# %%
from bleak import BleakScanner
import json

devs = await BleakScanner().discover(return_adv=True)
print(devs)
# Out:
# {'4B:FB:11:97:0E:08': (BLEDevice(4B:FB:11:97:0E:08, 4B-FB-11-97-0E-08), AdvertisementData(manufacturer_data={76: b'\x10\x05\n\x1cGy\x91'}, tx_power=17, rssi=-67)), '5C:85:7E:13:07:02': (BLEDevice(5C:85:7E:13:07:02, Flower care), AdvertisementData(local_name='Flower care', service_data={'0000fe95-0000-1000-8000-00805f9b34fb': b'q \x98\x00\xdd\x02\x07\x13~\x85\\\r\x08\x10\x01\x0b'}, service_uuids=['0000fe95-0000-1000-8000-00805f9b34fb'], rssi=-93)), 'C3:3D:4A:AC:6B:CB': (BLEDevice(C3:3D:4A:AC:6B:CB, C3-3D-4A-AC-6B-CB), AdvertisementData(manufacturer_data={76: b'\x12\x02\x00\x00'}, rssi=-73)), 'D0:03:DF:F1:B4:39': (BLEDevice(D0:03:DF:F1:B4:39, [TV] Samsung 7 Series (43)), AdvertisementData(local_name='[TV] Samsung 7 Series (43)', manufacturer_data={117: b'B\x04\x01\x01g\xd0\x03\xdf\xf1\xb49\xd2\x03\xdf\xf1\xb48\x06\x00\x00\x00\x00\x00\x00'}, rssi=-86)), 'F8:24:41:E6:3E:39': (BLEDevice(F8:24:41:E6:3E:39, XMCTD_), AdvertisementData(local_name='XMCTD_', manufacturer_data={356: b'\xf8$A\xe6
# ...

# %%
devs
# Out:
# {'4B:FB:11:97:0E:08': (BLEDevice(4B:FB:11:97:0E:08, 4B-FB-11-97-0E-08),
#   AdvertisementData(manufacturer_data={76: b'\x10\x05\n\x1cGy\x91'}, tx_power=17, rssi=-67)),
#  '5C:85:7E:13:07:02': (BLEDevice(5C:85:7E:13:07:02, Flower care),
#   AdvertisementData(local_name='Flower care', service_data={'0000fe95-0000-1000-8000-00805f9b34fb': b'q \x98\x00\xdd\x02\x07\x13~\x85\\\r\x08\x10\x01\x0b'}, service_uuids=['0000fe95-0000-1000-8000-00805f9b34fb'], rssi=-93)),
#  'C3:3D:4A:AC:6B:CB': (BLEDevice(C3:3D:4A:AC:6B:CB, C3-3D-4A-AC-6B-CB),
#   AdvertisementData(manufacturer_data={76: b'\x12\x02\x00\x00'}, rssi=-73)),
#  'D0:03:DF:F1:B4:39': (BLEDevice(D0:03:DF:F1:B4:39, [TV] Samsung 7 Series (43)),
#   AdvertisementData(local_name='[TV] Samsung 7 Series (43)', manufacturer_data={117: b'B\x04\x01\x01g\xd0\x03\xdf\xf1\xb49\xd2\x03\xdf\xf1\xb48\x06\x00\x00\x00\x00\x00\x00'}, rssi=-86)),
#  'F8:24:41:E6:3E:39': (BLEDevice(F8:24:41:E6:3E:39, XMCTD_),
# ...
